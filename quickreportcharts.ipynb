# %%
import pandas as pd

# %%
df = pd.read_csv('./subscribed_members.csv')

# %%
df.loc[df['students']==1].describe()
# Out:
#        Unnamed: 0        2021      FS2022  Faculty&Staff      Member  \
# count  214.000000  214.000000  214.000000          214.0  214.000000
# mean   121.915888    0.640187    0.242991            0.0    0.004673
# std     71.086487    0.481071    0.429895            0.0    0.068359
# min      0.000000    0.000000    0.000000            0.0    0.000000
# 25%     60.250000    0.000000    0.000000            0.0    0.000000
# 50%    123.500000    1.000000    0.000000            0.0    0.000000
# 75%    183.750000    1.000000    0.000000            0.0    0.000000
# max    243.000000    1.000000    1.000000            0.0    1.000000
#
#            SS2022    nan  students
# count  214.000000  214.0     214.0
# mean     0.116822    0.0       1.0
# std      0.321962    0.0       0.0
# min      0.000000    0.0       1.0
# 25%      0.000000    0.0       1.0
# 50%      0.000000    0.0       1.0
# 75%      0.000000    0.0       1.0
# max      1.000000    0.0       1.0

# %%
simple_analytics_table = pd.read_excel('./simple_analytics_table.xlsx')

# %%
simple_analytics_table
# Out:
#                          URL  Faculty&Staff  Member  students
# 0           2022-fall-events              1       1         1
# 1                      adanu              4       0         1
# 2           changingthecycle              2       1         2
# 3        healing-with-copper              2       1         1
# 4               join-the-sab              2       0         0
# 5  student-apha-presentation              3       2         0
# 6    violence-project-review              4       2         1
# 7    volunteer-opportunities              1       0         2

# %%
import seaborn as sns

# %%
simple_analytics_table.set_index('URL').describe()
# Out:
#        Faculty&Staff    Member  students
# count       8.000000  8.000000  8.000000
# mean        2.375000  0.875000  1.000000
# std         1.187735  0.834523  0.755929
# min         1.000000  0.000000  0.000000
# 25%         1.750000  0.000000  0.750000
# 50%         2.000000  1.000000  1.000000
# 75%         3.250000  1.250000  1.250000
# max         4.000000  2.000000  2.000000

# %%
students_opened = 79
students_total = 214

# %%
from matplotlib.pyplot import pie, axis, show, title

# %%
#axis('equal')
pie((students_opened, students_total), labels=('Opened 37%','Did not open 63%'))
title('Proportion of Non-SAB Students who Opened the Newsletter Email')
show()
